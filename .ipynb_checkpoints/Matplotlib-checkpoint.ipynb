# %% [markdown]
# <h2> Matplotlib </h2>

# %% [markdown]
# Goal: MATLAB -> It is a high-level programming language and a nu-merical computinn environment used by engineers and scientists for data analysis, visualization, and algorithmic devel-opment.Making it a populaar choice for mathematical and scientific computing.

# %% [markdown]
# <h4> Seaborn</h4>

# %% [markdown]
# seaborn is stylish and easy upgrade of matplotlib

# %% [markdown]
# <h4> Cufflinks <h4>

# %% [markdown]
# Cufflinks stylish upgrade of Seaborn

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
#   <h3> Matplotlib Basic</h3>

# %%
x = np.linspace(0,5,11)
x
y = x **3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x,y)
plt.title("Graph")
plt.xlabel(" X Axis")
plt.ylabel(" Y Axis")
# Out:
# Text(0, 0.5, ' Y Axis')

# %% [markdown]
# <h4> Subplots in Matplotlib</h4>

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,4)
plt.subplot(2,2,3)
plt.subplot(2,2,2)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(y,x)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)

# %% [markdown]
# <h4> Object oriented way</h4>

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# figsize is a tuple of the width and height of the figure in inches dpi is the dots-per-inch (pixel per inch).m

# %%
fig = plt.figure(figsize=(20,16), dpi = 100)
axis1 = fig.add_axes([0.2,0.1,0.5,0.8])
axis1.plot(x,y)
axis2 = fig.add_axes([0.3,0.4,0.9,0.8])
axis2.plot(x,y)

# %% [markdown]
# <h4>Types of Plots</h4>

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([15.,  5., 11., 12., 11.,  8.,  7.,  7., 14., 10.]),
#  array([  7., 105., 203., 301., 399., 497., 595., 693., 791., 889., 987.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2422f45aad0>,
#   <matplotlib.lines.Line2D at 0x2422f45ac10>],
#  'caps': [<matplotlib.lines.Line2D at 0x2422f45ad50>,
#   <matplotlib.lines.Line2D at 0x2422f45ae90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2422f45a990>],
#  'medians': [<matplotlib.lines.Line2D at 0x2422f45afd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2422f45b110>],
#  'means': []}

# %% [markdown]
# <h4> Saving Plots</h4>

# %%
fig = plt.figure()
ax= fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("Basicplot.png")

# %% [markdown]
# <h4> Working with Images</h4>

# %%
import matplotlib.image as mping
img = mping.imread('images.jpeg')
img
# Out:
# array([[[ 91,  91,  93],
#         [ 91,  91,  93],
#         [ 91,  91,  93],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122]],
#
#        [[ 91,  91,  93],
#         [ 91,  91,  93],
#         [ 91,  91,  93],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122]],
#
#        [[ 91,  91,  93],
#         [ 91,  91,  93],
#         [ 91,  91,  93],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122]],
#
#        ...,
#
#        [[245, 253, 255],
#         [245, 253, 255],
#         [245, 253, 255],
#         ...,
#         [153, 153, 153],
#         [153, 153, 153],
#         [153, 153, 153]],
#
#        [[245, 253, 255],
#         [245, 253, 255],
#         [245, 253, 255],
#         ...,
#         [153, 153, 153],
#         [153, 153, 153],
#         [153, 153, 153]],
#
#        [[245, 253, 255],
#         [245, 253, 255],
#         [245, 253, 255],
#         ...,
#         [153, 153, 153],
#         [153, 153, 153],
#         [153, 153, 153]]], shape=(678, 452, 3), dtype=uint8)

# %%
plt.imshow(img)

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(451.5), np.float64(677.5), np.float64(-0.5))

# %%
cropped_img = img[210:250 , 150:320]
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(169.5), np.float64(39.5), np.float64(-0.5))

# %% [markdown]
# <h4> Optional Designing</h4>

# %%
plt.plot(x,y,color = 'red')

# %%
xaxis = np.linspace(0,5,11)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(xaxis, xaxis+5, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
